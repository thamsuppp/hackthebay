# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point, Polygon, LineString
import fiona
from datetime import datetime
import shapely
import json

# %%
# Just a list of the HUCs I'm using - tried to get an even distribution of 8 data points from upstream to downstream
df = pd.read_csv("C:\\Users\\limzh\\Downloads\\huc_data.csv")
df = df[(df['NAME'] == 'Lower Sassafras River') | (df['NAME'] == 'Langford Creek') | (df['NAME'] == 'Severn River-Frontal Chesapeake Bay') | (df['NAME'] == 'Parkers Creek-Frontal Chesapeake Bay') | (df['NAME'] == 'Saint Leonard Creek-Patuxent River') | (df['NAME'] == 'Fox Creek-Honga River') | (df['NAME'] == 'Saint Jerome Creek-Frontal Chesapeake Bay') | (df['NAME'] == 'Cockrell Creek-Frontal Chesapeake Bay')] 
df
# Out:
#       Unnamed: 0        HUC12  Shape_Leng  Shape_Area      HUC12.1  \
# 39            39  20600060603    0.683814    0.011646  20600060603
# 271          271  20600020302    0.661976    0.014892  20600020302
# 279          279  20600020410    0.490307    0.011307  20600020410
# 339          339  20600040203    0.673728    0.010758  20600040203
# 344          344  20600040403    1.104189    0.011471  20600040403
# 345          345  20600040404    0.820220    0.009431  20600040404
# 369          369  20600050603    0.595375    0.010874  20600050603
# 1784        1784  20801020103    0.393942    0.003291  20801020103
#
#                                            NAME  centroid_long  centroid_lat
# 39           Saint Leonard Creek-Patuxent River     -76.498173     38.411304
# 271                       Lower Sassafras River     -75.963985     39.362469
# 279                              Langford Creek     -76.151131     39.173516
# ...
